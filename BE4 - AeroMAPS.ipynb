# %% [markdown]
# # **Partie 4 : Simulation et évaluation de scénarios durables pour l'aviation avec l'outil AeroMAPS**
# <a id="0"></a>
#
# Suite à vos différentes estimations technologiques lors des deux BE précédents, l'objectif de ce Notebook est de modéliser et d'évaluer des scénarios de transition pour le secteur aérien. Pour cela, l'outil AeroMAPS sera utilisé : il permet de simuler des scénarios prospectifs pour l’aviation et d’évaluer leur durabilité climatique et énergétique. L'utilisation d'AeroMAPS peut se faire de deux façons :
# - Via une interface graphique dédiée pour découvrir les principaux leviers et générer des premiers scénarios
# - Via des Jupyter Notebooks pour une utilisation plus poussée
#
# Sommaire :<br>
# [1. Tutoriel](#1)<br>
# [2. Simulation et évaluation de votre scénario de référence](#2)<br>
# [3. Optimisation de votre scénario](#3)<br>
# -----
# -----

# %% [markdown]
# ## 1. Tutoriel
# <a id="1"></a>
#
# L'objectif de cette partie est de prendre en main les bases de l'outil AeroMAPS via son interface graphique. Un tableau est à compléter tout au long du tutoriel.
#
# -----
#
# ### 1.1. Procédure de lancement de l'interface graphique d'AeroMAPS (5 minutes)
#
# Pour lancer l'interface graphique d'AeroMAPS, réalisez la procédure de lancement en rentrant les commandes suivantes (sous un ordinateur fixe démarré sous Linux).
#
# <img src="Images/Lancement_CAST.png" width="700">
#
# -----
# ### 1.2. Prise en main de l'interface graphique (10 minutes)
#
# Différents modes d’utilisation, plus ou moins complexes, sont disponibles sur AeroMAPS. Dans le cadre de cette étude, vous utiliserez uniquement le mode Découverte de l’outil. Un mode avancé est disponible si vous souhaitez approfondir les analyses.
# Les figures de gauche permettent d’afficher des graphes sur l’évolution des émissions de CO<sub>2</sub> ou du forçage radiatif de l’aviation. Les figures centrales permettent de réaliser des évaluations de durabilité climatique ou énergétique. Les figures de droite permettent d’afficher d’autres caractéristiques telles que l’évolution de la température ou les performances technologiques. Parcourrez les rapidement, notamment concernant les figures centrales.
# Les curseurs de gauche permettent de définir un scénario de transition pour le secteur aérien alors que les curseurs de droite définissent des caractéristiques environnementales globales. Utilisez les différents curseurs pour comprendre leurs impacts. Vous vous attarderez notamment sur les curseurs d’allocation et la manière de les interpréter dans les figures centrales.
# Pour plus d’informations, vous pouvez accéder au tutoriel de l’interface graphique disponible ici : https://aeromaps.github.io/AeroMAPS/books/documentation_gui.html

# %% [markdown]
# -----
# ### 1.3. Étude de scénarios durables (1 heure)
#
# Dans cette partie, des scénarios de transition pour l’aviation vont être modélisés et étudiés. Les aspects suivants vont être considérés successivement : une analyse climatique focalisée sur les émissions de CO<sub>2</sub>, une analyse énergétique et d’autres analyses spécifiques (non-CO<sub>2</sub> et mix électrique). Pour réaliser ces études, différentes hypothèses pour modéliser des scénarios représentatifs sont considérées.
# Concernant l’évolution du transport aérien, différents réglages sont proposés.  D’une part, des études de sensibilité seront réalisées pour évaluer l’influence de l’évolution du trafic aérien. Pour simplifier les analyses, vous devrez choisir des valeurs identiques pour l’évolution des différents marchés (passager court-moyen-long-courrier et fret). D’autre part, concernant les hypothèses technologiques, de nombreuses incertitudes demeurent sur les évolutions technologiques à venir pour les nouvelles générations d’avions. Par conséquent, trois scénarios représentatifs concernant les leviers d’action technologiques sont proposés et indiqués dans le tableau en annexe.
# En ce qui concerne les hypothèses climatiques et énergétiques globales, elles sont considérées communes à l’ensemble des scénarios étudiés. La température prise comme objectif sera +1,7°C avec 67% de chance de réussite, en considérant un faible développement des stratégies d’élimination du CO<sub>2</sub> atmosphérique (« Slightly developed »). Les disponibilités en biomasse et en électricité seront considérées comme réalistes et optimistes respectivement. Enfin, des études de sensibilité seront aussi réalisées concernant les variables d’allocation d’objectifs environnementaux. Des comparaisons avec des valeurs de référence seront notamment réalisées.
#
# #### 1.3.1. Analyse climatique focalisée sur les émissions de CO<sub>2</sub>
#
# Dans cette section, une analyse de la durabilité climatique des scénarios est proposée. Les analyses se limiteront aux seules émissions de CO<sub>2</sub> de l’aviation. Après une évaluation des performances des scénarios technologiques représentatifs, deux démarches d’analyse de scénarios sont proposées, en jouant sur les variables restantes : l’évolution du trafic aérien et l’allocation d’un objectif climatique via un budget carbone.
#
# ##### 1.3.1.1. Évaluation des caractéristiques trois scénarios technologiques de référence
#
# Pour chaque scénario technologique représentatif, estimez les émissions moyennes de CO<sub>2</sub> par passager-kilomètre pour la flotte d’avions en 2050 en utilisant un graphe adapté parmi les figures de droite. Complétez le tableau.
#
# ##### 1.3.1.2. Démarche 1 : Détermination de la part du budget carbone consommée
#
# On choisit de considérer une croissance tendancielle du trafic aérien, à savoir 3% par an.
# Pour chaque scénario technologique représentatif, déterminez la part du budget carbone mondial consommée par le secteur aérien.
# Complétez le tableau en annexe et commentez la plage de variation que vous obtenez.
# Quels sont les avantages/inconvénients de cette démarche ?
#
# ##### 1.3.1.3. Démarche 2 : Détermination de l’évolution durable du trafic aérien
#
# On choisit cette fois-ci de procéder de façon opposée en fixant une part allouée au secteur. Pour un budget carbone alloué à l’aviation, on cherche le taux de (dé)croissance annuel du trafic aérien qui permet d’équilibrer les émissions cumulées de CO<sub>2</sub> avec ce budget carbone alloué.
# Pour chacun des scénarios technologiques représentatifs, déterminez le taux de (dé)croissance annuel du trafic aérien durable correspondant. Vous réaliserez cette étude pour une allocation de 3,4% (allocation indirecte du scénario ETP 2014 de l’AIE) et pour une allocation de 2,6% (approche dite grandfathering, correspondant à la part de l’aviation dans les émissions mondiales de CO<sub>2</sub> en 2019).
# Complétez le tableau en annexe et commentez la plage de variation que vous obtenez.
# Quels sont les avantages/inconvénients de cette démarche ?

# %% [markdown]
# > **Réponses**

# %% [markdown]
# #### 1.3.2. Analyse énergétique
#
# Dans cette section, une analyse de la consommation de ressources énergétiques est réalisée. Cette dernière se focalise sur la biomasse et l’électricité. Vous utiliserez les différents scénarios technologiques représentatifs couplés avec les taux d’évolution du trafic aérien déterminés précédemment pour le respect d’une allocation de budget carbone de 2,6%. De plus, deux scénarios technologiques alternatifs sont proposés dans le tableau en annexe, ces derniers se basant exclusivement sur les biocarburants ou les électrocarburants (hors hydrogène).
#
# ##### 1.3.2.1. Consommation de biomasse
#
# Pour chaque scénario, déterminez la part de la biomasse mondiale consommée. Vous pourrez utiliser un graphe adapté parmi les figures centrales. Complétez le tableau.
# Commentez ces valeurs par rapport aux allocations proposées dans AeroMAPS pour la biomasse.
# Dans le cas d’un scénario avec une faible disponibilité en biomasse à l’échelle mondiale et d’une croissance annuelle du trafic aérien de 3%, quelle part maximale de la biomasse pourrait être consommée par l’aviation ? Commentez.
#
# ##### 1.3.2.2. Consommation d'électricité
#
# Procédez à la même analyse mais en considérant cette fois-ci l’électricité comme ressource énergétique d’intérêt.

# %% [markdown]
# > **Réponses**

# %% [markdown]
# #### 1.3.3. Autres analyses spécifiques (non-CO<sub>2</sub> et mix électrique)
#
# Dans cette dernière section, d’autres analyses sont proposées pour mettre en valeur certaines caractéristiques particulièrement intéressantes. Vous utiliserez les différents scénarios technologiques représentatifs couplés avec les taux d’évolution du trafic aérien déterminés précédemment pour le respect d’une allocation de budget carbone de 2,6%.
#
# ##### 1.3.3.1. Prise en compte des effets non-CO<sub>2</sub>
#
# Dans la section précédente, seules les émissions de CO<sub>2</sub> ont été considérées pour définir des scénarios durables. L’objectif de cette partie est de directement regarder l'impact sur l'évolution de température.
# Pour réduire les effets non-CO<sub>2</sub>, des stratégies spécifiques peuvent être mises en place, par exemple pour réduire la formation des traînées de condensation. On considère par exemple ici l’utilisation de stratégies d’évitement pour réduire l’impact de ces dernières.
# Dans un premier temps, on ne considère pas l’utilisation de stratégies d’évitement. En utilisant un graphe parmi les figures de droite, déterminez l’élévation de température induite par l’aviation en 2050, ainsi que l’évolution entre 2019 et 2050.
# Dans un second temps, procédez à la même démarche en considérant l’utilisation de stratégies d’évitement.
# Complétez le tableau et discutez des valeurs obtenues.
#
# ##### 1.3.3.2. Influence du mix électrique
#
# L’électricité peut être utilisée pour produire certains vecteurs énergétiques tels que l’hydrogène ou les électrocarburants. Par conséquent, les caractéristiques environnementales de ces vecteurs énergétiques dépendent fortement des caractéristiques du mix électrique.
# Pour illustrer cet aspect, vous utiliserez le scénario technologique représentatif 3, pour lequel vous considèrerez l’option « Low-carbon » pour la production d’électricité. Cette option consiste en une transition vers un mix relativement bas-carbone à l’échelle mondiale entre 2019 et 2050.
# À partir du graphe adapté parmi les figures de droite, déterminez l’année à partir de laquelle l’utilisation d’hydrogène permet d’émettre moins de CO2 que l’utilisation du kérosène (en considérant une iso-efficacité énergétique entre les avions conventionnels et ceux à hydrogène). Dit autrement, vous chercherez donc à comparer les facteurs d’émission (de CO2) des carburants. Procédez de la même façon pour les électrocarburants.
# Complétez le tableau et commentez les résultats.

# %% [markdown]
# > **Réponses**

# %% [markdown]
# #### 1.3.5. Tableau récapitulatif
# <a id="10"></a>
#
# Vous trouverez ci-dessous le tableau récapitulatif dont vous deverez compléter les cellules indiquées (HERE).

# %% [markdown]
# |Données et questions|Variable dans AeroMAPS|Scénario 1|Scénario 2|Scénario 3|Scénario 3B|Scénario 3E|Unité|Description|
# |--|--|--|--|--|--|--|--|--|
# |Paramètres technologiques|Aircraft efficiency|Renewal|Accelerated|Ambitious|Ambitious|Ambitious|[-]|Réglage de l'amélioration de l'efficacité énergétique des avions|
# |Paramètres technologiques|Operations|Constant|Realistic|Optimistic|Optimistic|Optimistic|[-]|Réglage de l'amélioration des opérations en vol et au sol|
# |Paramètres technologiques|Load factor|Unambitious|Trend|Ambitious|Ambitious|Ambitious|[-]|Réglage de l'amélioration du taux de remplissage des avions|
# |Paramètres technologiques|Energy mix|Kerosene|ReFuelEU|ReFuelEU|ReFuelEU|ReFuelEU|[-]|Réglage du mix énergétique de l'aviation (hors hydrogène)|
# |Paramètres technologiques|Hydrogen aircraft|Absence|Limited|Ambitious|Ambitious|Ambitious|[-]|Réglage de l'introduction d'avions à hydrogène dans la flotte|
# |Paramètres technologiques|Biofuel production|/|Current|Low-carbon|Low-carbon|Low-carbon|[-]|Réglage des caractéristiques de production des biocarburants|
# |Paramètres technologiques|Hydrogen production|/|Gas without CCS|Electrolysis|Electrolysis|Electrolysis|[-]|Réglage des caractéristiques de production de l'hydrogène|
# |Paramètres technologiques|Electricity production|/|Low-carbon|Dedicated low-carbon|Dedicated low-carbon|Dedicated low-carbon|[-]|Réglage des caractéristiques de production de l'électricité|
# |1.3.1.1.|/|HERE|HERE|HERE|/|/|[gCO2eq/RPK]|Émissions globales moyennes de CO2 par passager-kilomètre pour la flotte d'avions en 2050|
# |1.3.1.2.|/|HERE|HERE|HERE|/|/|[%]|Part du budget carbone mondial consommée par l'aviation pour une croissance annuelle du trafic aérien de 3%|
# |1.3.1.3.|Variables de Air Traffic|HERE|HERE|HERE|/|/|[%]|Taux de (dé)croissance annuel du trafic aérien pour équilibrer avec le budget carbone du secteur pour une allocation de 3,4%|
# |1.3.1.3.|Variables de Air Traffic|HERE|HERE|HERE|/|/|[%]|Taux de (dé)croissance annuel du trafic aérien pour équilibrer avec le budget carbone du secteur pour une allocation de 3,4%. Vous conserverez cette valeur dans la suite !|
# |1.3.2.1.|/|HERE|HERE|HERE|HERE|HERE|[%]|Part de la biomasse mondiale consommée par l'aviation en 2050|
# |1.3.2.2.|/|HERE|HERE|HERE|HERE|HERE|[%]|Part de l'électricité mondiale consommée par l'aviation en 2050|
# |1.3.3.1.|Sans "Contrails avoidance strategies"|HERE|HERE|HERE|/|/|[mK]|Augmentation de température induite par l'aviation en 2050 (totale et vs 2019)|
# |1.3.3.1.|Avec "Contrails avoidance strategies"|HERE|HERE|HERE|/|/|[mK]|Augmentation de température induite par l'aviation en 2050 (totale et vs 2019)|
# |1.3.3.2.|Low-carbon pour Electricity production|/|/|HERE|/|/|[yr]|Années à partir desquelles l'hydrogène et les électrocarburants deviennent plus intéressants que le kérosène|

# %% [markdown]
# -----
# -----
# ## 2. Simulation et évaluation de votre scénario de référence (30 minutes)
# <a id="2"></a>
#
# Maintenant que vous avez découvert les principales fonctionnalités d'AeroMAPS, vous allez pouvoir simuler et évaluer votre propre scénario de référence en utilisant directement des Jupyter Notebooks. Différentes variables devront être réglées en fonction des choix que vous avez fait dans les précédents BE. Pour les variables que vous n'avez pas étudié durant les précédents BE, vous pouvez considérer les valeurs médianes proposées.
#
# Le scénario que vous avez défini est-il durable d'un point de vue climatique ? D'un point de vue énergétique ? Commentez.

# %% [markdown]
# > **Réponses**

# %%
# %matplotlib widget
from aeromaps.core.process import create_process
from aeromaps.core.models import models_complex
from aeromaps.models.air_transport.aircraft_fleet_and_operations.fleet.fleet_model import (
    Fleet,
    AircraftParameters,
    Aircraft,
)
process = create_process(
    models=models_complex,
    use_fleet_model=True,
    add_examples_aircraft_and_subcategory=False,
)

# %%
# Evolution du trafic aérien par catégorie et par décennie [%]
process.parameters.cagr_passenger_short_range_reference_periods = [2020, 2030, 2040, 2050]
process.parameters.cagr_passenger_short_range_reference_periods_values = [3.0, 2.0, 1.0]
process.parameters.cagr_passenger_medium_range_reference_periods = []
process.parameters.cagr_passenger_medium_range_reference_periods_values = [3.0]
process.parameters.cagr_passenger_long_range_reference_periods = []
process.parameters.cagr_passenger_long_range_reference_periods_values = [3.0]
process.parameters.cagr_freight_reference_periods = []
process.parameters.cagr_freight_reference_periods_values = [3.0]

# %%
# Amélioration de l'efficacité énergétique des avions via le taux de remplissage

## Valeur du taux de remplissage en 2050 [%]
process.parameters.load_factor_end_year = 85  # 2019 value: 82.399312

# %%
# Amélioration de l'efficacité énergétique des avions via le renouvellement de flotte

# Aircraft fleet

## Initialization
fleet = process.fleet

## Short Range
short_range_aircraft_params = AircraftParameters(
    entry_into_service_year=2035,
    consumption_evolution=-20.0,
    nox_evolution=-75.0,
    soot_evolution=-100.0,
    doc_non_energy_evolution=10.0,
    cruise_altitude=12000.0,
)
short_range_aircraft = Aircraft(
    "New Short-range Aircraft", parameters=short_range_aircraft_params, energy_type="HYDROGEN"
)
fleet.categories["Short Range"].subcategories[0].add_aircraft(aircraft=short_range_aircraft)

## Medium Range
medium_range_aircraft_params = AircraftParameters(
    entry_into_service_year=2035,
    consumption_evolution=-20.0,
    nox_evolution=0.0,
    soot_evolution=0.0,
    doc_non_energy_evolution=0.0,
    cruise_altitude=12000.0,
)
medium_range_aircraft = Aircraft(
    "New Medium-range Aircraft", parameters=medium_range_aircraft_params, energy_type="DROP_IN_FUEL"
)
fleet.categories["Medium Range"].subcategories[0].add_aircraft(aircraft=medium_range_aircraft)

## Long Range
long_range_aircraft_params = AircraftParameters(
    entry_into_service_year=2035,
    consumption_evolution=-20.0,
    nox_evolution=0.0,
    soot_evolution=0.0,
    doc_non_energy_evolution=0.0,
    cruise_altitude=12000.0,
)
long_range_aircraft = Aircraft(
    "New Long-range Aircraft", parameters=long_range_aircraft_params, energy_type="DROP_IN_FUEL"
)
fleet.categories["Long Range"].subcategories[0].add_aircraft(aircraft=long_range_aircraft)

## Fleet renewal
fleet.categories["Short Range"].parameters.life = 20
fleet.categories["Medium Range"].parameters.life = 20
fleet.categories["Long Range"].parameters.life = 20

# %%
# Amélioration de l'efficacité énergétique des avions via les opérations

## Valeurs pour régler la fonction sigmoïde
process.parameters.operations_final_gain = 8.0  # [%]
process.parameters.operations_start_year = 2025
process.parameters.operations_duration = 25.0

# %%
# Introduction de carburants drop-in alternatifs

## Part des carburants dans le mix des carburants drop-in (le reste étant complété par du kérosène) [%]
process.parameters.biofuel_share_reference_years = [2020, 2030, 2040, 2050]
process.parameters.biofuel_share_reference_years_values = [0.0, 4.8, 24.0, 35.0]
process.parameters.electrofuel_share_reference_years = [2020, 2030, 2040, 2050]
process.parameters.electrofuel_share_reference_years_values = [0.0, 1.2, 10.0, 35.0]

# %%
# Limites environnementales

## Carbon budgets and Carbon Dioxide Removal [GtCO2]
process.parameters.net_carbon_budget = 850.0
process.parameters.carbon_dioxyde_removal_2100 = 280.0

## Available energy resources in 2050 [EJ]
process.parameters.waste_biomass = 12
process.parameters.crops_biomass = 63
process.parameters.forest_residues_biomass = 17
process.parameters.agricultural_residues_biomass = 57
process.parameters.algae_biomass = 15
process.parameters.available_electricity = 250.0

# %%
# Règles d'allocation

## Aviation share of the global (equivalent) carbon budget [%]
process.parameters.aviation_carbon_budget_allocated_share = 2.6
process.parameters.aviation_equivalentcarbonbudget_allocated_share = 5.1

## Aviation share of the global energy resources (biomass and electricity) [%]
process.parameters.aviation_biomass_allocated_share = 5.0
process.parameters.aviation_electricity_allocated_share = 5.0

# %%
# Réglages environnementaux divers

## Share of biofuel production pathways (the rest being completed by AtJ processes) [%]
process.parameters.biofuel_hefa_fog_share_reference_years = [2020, 2030, 2040, 2050]
process.parameters.biofuel_hefa_fog_share_reference_years_values = [100, 100, 0.7, 0.7]
process.parameters.biofuel_hefa_others_share_reference_years = [2020, 2030, 2040, 2050]
process.parameters.biofuel_hefa_others_share_reference_years_values = [0.0, 0.0, 3.8, 3.8]
process.parameters.biofuel_ft_others_share_reference_years = [2020, 2030, 2040, 2050]
process.parameters.biofuel_ft_others_share_reference_years_values = [0.0, 0.0, 76.3, 76.3]
process.parameters.biofuel_ft_msw_share_reference_years = [2020, 2030, 2040, 2050]
process.parameters.biofuel_ft_msw_share_reference_years_values = [0.0, 0.0, 7.4, 7.4]

## Emission factors for electricity (2019 value: 429 gCO2/kWh)
process.parameters.electricity_emission_factor_reference_years = [2020, 2030, 2040, 2050]
process.parameters.electricity_emission_factor_reference_years_values = [429.0, 200.0, 100.0, 30.0]

## Share of hydrogen production pathways (the rest being completed by production via coal without CCS) [%]
## Distribution in 2019: Gas without CCS (71%), Coal without CCS (27%), Electrolysis (2%), Others with CCS (0%), Co-products not taken into account
process.parameters.hydrogen_electrolysis_share_reference_years = [2020, 2030, 2040, 2050]
process.parameters.hydrogen_electrolysis_share_reference_years_values = [2, 100, 100, 100]
process.parameters.hydrogen_gas_ccs_share_reference_years = [2020, 2030, 2040, 2050]
process.parameters.hydrogen_gas_ccs_share_reference_years_values = [0, 0, 0, 0]
process.parameters.hydrogen_coal_ccs_share_reference_years = [2020, 2030, 2040, 2050]
process.parameters.hydrogen_coal_ccs_share_reference_years_values = [0, 0, 0, 0]
process.parameters.hydrogen_gas_share_reference_years = [2020, 2030, 2040, 2050]
process.parameters.hydrogen_gas_share_reference_years_values = [71, 0, 0, 0]

# %%
process.compute()

# %%
# Pour afficher les résultats en détail
# process.data["float_outputs"]
# process.data["vector_outputs"]
# process.data["climate_outputs"]

# %%
process.plot("air_transport_co2_emissions", save=False)
# Out:
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
process.plot("multidisciplinary_assessment", save=False)
# Out:
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
process.plot("temperature_increase_from_air_transport", save=False)
# Out:
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
process.plot("emission_factor_per_fuel", save=False)
# Out:
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %% [markdown]
# -----
# -----
# ## 3. Optimisation de votre scénario (30 minutes)
# <a id="3"></a>
#
# L'objectif de cette dernière partie est de corriger et d'améliorer votre scénario afin d'obtenir un scénario durable pour l'aviation que vous présenterez aux autres étudiants. Vous devrez présenter les hypothèses mondiales globales (objectif de température, capture et stockage de carbone, mix électrique...), la trajectoire des émissions de CO<sub>2</sub>, la part du budget carbone consommé correspondante et les consommations énergétiques avec les parts allouées correspondantes pour la biomasse et l'électricité. Même si les leviers spécifiques aux effets non-CO<sub>2</sub> ne sont pas considérés dans ces scénarios, vous pouvez aussi analyser les résultats en terme de température.
#
# Justifiez et détaillez votre démarche. Commentez les résultats que vous obtenez.

# %% [markdown]
# > **Réponses**
